# %%
import pandas as pd

# %%
df = pd.read_parquet("../data/processed/asrs/ASRS_embeddings.parquet")

# %%
df.head()
# Out:
#                                            narrative    Time  \
# 0     Narrative Callback Narrative Callback Synopsis    Date
# 1  The weather at TPA on the arrival was 1/4 SM a...  202301
# 2  On descent into ZZZ setting up for the ILS XX ...  202301
# 3  A Ramp Agent brought me a battery powered whee...  202301
# 4  I was hand flying the ILS 20R into SNA and was...  202301
#
#               Place        Environment     phase aircraft_type airport  \
# 0  Locale Reference  Flight Conditions      None          None    None
# 1       TPA.Airport                IMC      Taxi          None     THE
# 2       ZZZ.Airport                IMC      Taxi          None    INTO
# 3              None               None      None          B737    RAMP
# 4        SCT.TRACON                VMC  Approach          None     WAS
#
#                                            embedding
# 0  [0.004298643209040165, -0.0037726161535829306,...
# 1  [0.03323395550251007, -0.032404638826847076, 0...
# ...

# %%
df.shape
# Out:
# (4584, 8)

# %%
len(df["embedding"][0])
# Out:
# 768
