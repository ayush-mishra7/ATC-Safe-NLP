# %%
import os
import pathlib
import joblib
import pandas as pd

# %%
# %pwd
# Out:
# 'c:\\PROJECTS\\ML Projects\\ATC-Safe-NLP\\research'

# %%
cd ../
# Out:
# c:\PROJECTS\ML Projects\ATC-Safe-NLP

# %%
# %pwd
# Out:
# 'c:\\PROJECTS\\ML Projects\\ATC-Safe-NLP'

# %%
df = pd.read_parquet("data/processed/asrs/ASRS_labeled.parquet")

# %%
print(df.columns)
# Out:
# Index(['narrative', 'Time', 'Place', 'Environment', 'phase', 'aircraft_type',
#        'airport', 'embedding', 'umap_x', 'umap_y', 'cluster', 'cluster_label'],
#       dtype='object')
