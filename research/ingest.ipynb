# %%
import pandas as pd
df = pd.read_parquet("../data/processed/asrs/ASRS_clean.parquet")
print(df.head())
print(df.shape)
# Out:
#                                            narrative    Time  \
# 0     Narrative Callback Narrative Callback Synopsis    Date
# 1  The weather at TPA on the arrival was 1/4 SM a...  202301
# 2  On descent into ZZZ setting up for the ILS XX ...  202301
# 3  A Ramp Agent brought me a battery powered whee...  202301
# 4  I was hand flying the ILS 20R into SNA and was...  202301
#
#               Place        Environment
# 0  Locale Reference  Flight Conditions
# 1       TPA.Airport                IMC
# 2       ZZZ.Airport                IMC
# 3              None               None
# 4        SCT.TRACON                VMC
# (4584, 4)

# %%
import pandas as pd

df_raw = pd.read_csv("../data/raw/ASRS_DBOnline.csv", encoding="ISO-8859-1", low_memory=False)
df_raw.head()
df_raw.columns
df_raw.shape
# Out:
# (4585, 126)

# %%
list(df_raw.columns)
# Out:
# [' ',
#  'Time',
#  'Time.1',
#  'Place',
#  'Place.1',
#  'Place.2',
#  'Place.3',
#  'Place.4',
#  'Place.5',
#  'Place.6',
#  'Environment',
#  'Environment.1',
#  'Environment.2',
#  'Environment.3',
#  'Environment.4',
#  'Environment.5',
#  'Aircraft 1',
#  'Aircraft 1.1',
#  'Aircraft 1.2',
#  'Aircraft 1.3',
#  'Aircraft 1.4',
#  'Aircraft 1.5',
#  'Aircraft 1.6',
#  'Aircraft 1.7',
#  'Aircraft 1.8',
#  'Aircraft 1.9',
#  'Aircraft 1.10',
#  'Aircraft 1.11',
#  'Aircraft 1.12',
#  'Aircraft 1.13',
#  'Aircraft 1.14',
#  'Aircraft 1.15',
#  'Aircraft 1.16',
#  'Aircraft 1.17',
#  'Aircraft 1.18',
#  'Aircraft 1.19',
#  'Aircraft 1.20',
#  'Aircraft 1.21',
#  'Aircraft 1.22',
#  'Aircraft 1.23',
#  'Aircraft 1.24',
#  'Aircraft 1.25',
#  'Aircraft 1.26',
#  'Aircraft 1.27',
#  'Aircraft 1.28',
#  'Aircraft 1.29',
#  'Aircraft 1.30',
#  'Aircraft 1.31',
#  'Aircraft 1.32',
#  'Aircraft 1.33',
#  'Aircraft 1.34',
#  'Component',
#  'Component.1',
#  'Component.2',
# ...

# %%
[x for x in df_raw.columns if "report" in x.lower()]
# Out:
# ['Report 1', 'Report 1.1', 'Report 2', 'Report 2.1', 'Report 1.2']
