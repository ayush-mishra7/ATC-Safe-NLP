# %%
import pandas as pd

# %%
df = pd.read_parquet("../data/processed/asrs/ASRS_labeled.parquet")

# %%
df[["cluster", "cluster_label"]].head()
# Out:
#    cluster                  cluster_label
# 0        9            Altitude / ATC Comm
# 1        5         Runway Ops / Clearance
# 2        8      Landing Gear / Mechanical
# 3        1       Hazmat / Dangerous Goods
# 4       10  Drone / Unauthorized Airspace

# %%
df["cluster_label"].value_counts()
# Out:
# cluster_label
# Engine / Fuel / Mechanical       521
# NMAC / Traffic Pattern           469
# Weather / Wake Turbulence        469
# Taxi / Ramp Ground Ops           421
# Altitude / ATC Comm              408
# Landing Gear / Mechanical        387
# Training / Student Landing       386
# Approach / Terrain Awareness     385
# Cabin / Smoke / Maintenance      348
# Hazmat / Dangerous Goods         325
# Runway Ops / Clearance           304
# Drone / Unauthorized Airspace    161
# Name: count, dtype: int64

# %%
# For Tableau

df.to_csv("../data/exports/ASRS_labeled.csv", index=False)
