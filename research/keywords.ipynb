# %%
import pandas as pd

# %%
pd.read_csv("../data/processed/asrs/ASRS_cluster_summary.csv")
# Out:
#     cluster                                           keywords
# 0         0  approach, altitude, terrain, ft, visual, gps, ...
# 1         1  dg, hazmat, goods, dangerous, nan, cargo, load...
# 2         2  aircraft, taxiway, ramp, taxi, gate, tug, grou...
# 3         3  engine, fuel, power, oil, nan, zzz, flight, la...
# 4         4  aircraft, traffic, pattern, nan, nmac, runway,...
# 5         5  runway, aircraft, traffic, tower, short, final...
# 6         6  cabin, smoke, flight, maintenance, engine, cre...
# 7         7  runway, aircraft, landing, left, student, nan,...
# 8         8  gear, maintenance, landing, aircraft, flight, ...
# 9         9  aircraft, ft, altitude, controller, approach, ...
# 10       10  drone, uas, nan, airspace, ft, authorization, ...
# 11       11  turbulence, wake, aircraft, flight, autopilot,...
